# %% [markdown]
# https://bit.ly/PYDA-5-files

# %% [markdown]
# # Работа с файлами
# - Прочитать файл из другой папки
# - Пример группировки большого файла cards.csv
# - Строки с запятыми
# - Кодировки файлов ([статья 1](https://tproger.ru/translations/unicode-and-encoding-python-guide/) и [статья 2](https://pythononline.ru/osnovy/encode-decode))
# - Формат JSON

# %%
# https://drive.google.com/file/d/1KzcFfr-OKU9oNna6Ttl15RL6c742Unmb/view?usp=drive_link

# %%
# !wget 'https://drive.google.com/uc?id=1KzcFfr-OKU9oNna6Ttl15RL6c742Unmb' -O cards.csv
# !mkdir logs
# !wget 'https://drive.google.com/uc?id=1KzcFfr-OKU9oNna6Ttl15RL6c742Unmb' -O logs/cards.csv
# !wget 'https://drive.google.com/uc?id=1EOJUHPYxoR-day3qBnOsXy5x3c8xLhxh' -O purchase_log.txt
# !wget 'https://drive.google.com/uc?id=1swdGQ3fLkSd-k4eFdphFuzSJ-CLG5v2n' -O visit_log.csv
# !wget 'https://drive.google.com/uc?id=1xl7yg9ZxXSFaexzEXCPPUbDUCjolu_gF' -O sample.csv
# Out:
# --2023-10-13 05:59:31--  https://drive.google.com/uc?id=1KzcFfr-OKU9oNna6Ttl15RL6c742Unmb
# Resolving drive.google.com (drive.google.com)... 172.253.63.102, 172.253.63.100, 172.253.63.139, ...
# Connecting to drive.google.com (drive.google.com)|172.253.63.102|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0s-84-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/2smrf6l078amkt977a4547g6jjtnfnrm/1697176725000/02611596255248067438/*/1KzcFfr-OKU9oNna6Ttl15RL6c742Unmb?uuid=6f7794e3-0cde-4015-830e-be24a0a941e4 [following]
# ...
# --2023-10-13 05:59:31--  https://doc-0s-84-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/2smrf6l078amkt977a4547g6jjtnfnrm/1697176725000/02611596255248067438/*/1KzcFfr-OKU9oNna6Ttl15RL6c742Unmb?uuid=6f7794e3-0cde-4015-830e-be24a0a941e4
# Resolving doc-0s-84-docs.googleusercontent.com (doc-0s-84-docs.googleusercontent.com)... 142.251.167.132, 2607:f8b0:4004:c1d::84
# ...

# %%
# файл рядом с кодом
f = open('cards.csv')

# %%
# вложенная папка
f = open('logs/cards.csv')  # относительный путь

# %%
# !pwd
# Out:
# /content

# %%
# Mac, Ubuntu, CentOS
# f = open('/Users/kbashevoy/Desktop/Нетология/Занятия/Занятие 5/cards.csv')  # абсолютный путь
f = open('/content/cards.csv')  # абсолютный путь

# %%
print('C:\\Users\\kbashevoy\\cards.csv')
# Out:
# C:\Users\kbashevoy\cards.csv

# %%
# Windows
f = open('C:\Users\kbashevoy\cards.csv')

# \ - символ переноса строки
# поэтому нужно экранирование
f = open('C:\\Users\\kbashevoy\\cards.csv')

f = open(r'C:\Users\kbashevoy\cards.csv')

# если в адресе есть пробелы и нелатинские буквы - перенос в другую папку
f = open(r'C:\Users\kbashevoy\Нетология 5\cards.csv')

# %%
text = 'очень длинный \
текст'

text
# Out:
# 'очень длинный текст'

# %% [markdown]
# ## Группировка в больших файлах
# Сколько раз каждая масть встречалась в файле?

# %%
f = open('cards.csv')

content = f.readlines() # считывает в RAM, если данных немного, то ок
content[:10]
# Out:
# ['червы,4\n',
#  'пики,4\n',
#  'червы,10\n',
#  'бубны,10\n',
#  'червы,5\n',
#  'пики,9\n',
#  'трефы,дама\n',
#  'червы,3\n',
#  'трефы,6\n',
#  'пики,5\n']

# %%
# при знакомстве с данными выводить все строки не разумно
f = open('cards.csv')

for line in f:
    print(line)
# Out:
# Streaming output truncated to the last 5000 lines.
# трефы,валет
#
# пики,6
#
# пики,валет
#
# червы,1
#
# пики,7
#
# бубны,2
#
# трефы,9
#
# бубны,8
#
# бубны,6
#
# трефы,7
#
# червы,6
#
# бубны,5
#
# трефы,1
#
# пики,4
#
# трефы,8
#
# червы,6
#
# червы,9
#
# пики,6
#
# пики,5
#
# бубны,1
#
# бубны,валет
#
# бубны,3
#
# червы,1
#
# червы,9
#
# пики,7
#
# червы,9
#
# пики,7
#
# червы,туз
#
# трефы,3
#
# трефы,король
#
# трефы,2
#
# пики,4
#
# бубны,8
#
# трефы,король
#
# трефы,4
#
# бубны,5
#
# червы,5
#
# червы,8
#
# бубны,4
#
# трефы,1
#
# червы,10
#
# трефы,10
#
# пики,10
#
# бубны,5
#
# червы,6
#
# бубны,король
#
# червы,5
#
# бубны,10
#
# червы,туз
#
# трефы,туз
#
# трефы,туз
#
# трефы,король
#
# трефы,10
#
# трефы,1
#
# трефы,4
#
# пики,5
#
# трефы,6
#
# трефы,6
#
# червы,10
#
# пики,7
#
# червы,2
#
# пики,1
#
# червы,8
#
# трефы,3
#
# червы,3
#
# пики,1
#
# пики,дама
#
# червы,9
#
# трефы,дама
#
# трефы,5
#
# трефы,3
#
# трефы,король
#
# бубны,8
#
# пики,8
#
# трефы,1
#
# ...

# %%
f = open('cards.csv')

# при знакомстве с данными выводить все строки не разумно, берем индексы
for i, line in enumerate(f):
    # line = line.strip()
    line = line.strip().split(',')
    print(i, line)
    if i > 5:
        break
# Out:
# 0 ['червы', '4']
# 1 ['пики', '4']
# 2 ['червы', '10']
# 3 ['бубны', '10']
# 4 ['червы', '5']
# 5 ['пики', '9']
# 6 ['трефы', 'дама']

# %%
f = open('cards.csv')

for i, line in enumerate(f):
    line = line.strip().split(',')

    # получаем карту
    suit = line[0]
    value = line[1]
    print(suit, value)

    if i > 5:
        break
# Out:
# червы 4
# пики 4
# червы 10
# бубны 10
# червы 5
# пики 9
# трефы дама

# %%
f = open('cards.csv')

for i, line in enumerate(f):
    line = line.strip().split(',')

    # получаем карту
    # suit = line[0]
    # value = line[1]

    suit, _ = line  # количество переменных == с длиной списка

    print(suit)

    if i > 5:
        break
# Out:
# червы
# пики
# червы
# бубны
# червы
# пики
# трефы

# %%
f = open('cards.csv')

for i, line in enumerate(f):
    line = line.strip().split(',')

    suit, _ = line  # количество переменных == с длиной списка

    # создать 4 переменные - мастей может быть много
    # собрать все масти в список - большой расходов по памяти

    if i > 5:
        break

# %%
# собрать все масти в список - большой расходов по памяти
from collections import Counter

Counter(['червы', 'пики', 'червы', 'червы', 'пики', 'трефы', 'червы'])
# Out:
# Counter({'червы': 4, 'пики': 2, 'трефы': 1})

# %%
d = {'червы': 2, 'пики': 1, 'ЧЕРВЫ': 1, 'error': 3}
d
# Out:
# {'червы': 2, 'пики': 1, 'ЧЕРВЫ': 1, 'error': 3}

# %%
f = open('cards.csv')

stats = {}

for i, line in enumerate(f):
    line = line.strip().split(',')

    suit, _ = line  # количество переменных == с длиной списка

    # если такого ключа нет, то будет ошибка
    # stats[suit] += 1

    if suit in stats:
        stats[suit] += 1
    else:
        # точно на первой строке
        stats[suit] = 1

    print(stats)

    if i > 5:
        break
# Out:
# {'червы': 1}
# {'червы': 1, 'пики': 1}
# {'червы': 2, 'пики': 1}
# {'червы': 2, 'пики': 1, 'бубны': 1}
# {'червы': 3, 'пики': 1, 'бубны': 1}
# {'червы': 3, 'пики': 2, 'бубны': 1}
# {'червы': 3, 'пики': 2, 'бубны': 1, 'трефы': 1}

# %%
d.setdefault('червы', 0)
d.setdefault('трефы', 0)
d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d01e1571932a> in <cell line: 1>()
# ----> 1 d.setdefault('червы', 0)
#       2 d.setdefault('трефы', 0)
#       3 d
#
# NameError: name 'd' is not defined

# %%
f = open('cards.csv')

stats = {}

for i, line in enumerate(f):
    line = line.strip().split(',')

    suit, _ = line

    stats.setdefault(suit, 0)
    stats[suit] += 1

print(stats)

# %% [markdown]
# ## Строки с запятыми

# %%
f = open('sample.csv')
f.readlines()
# Out:
# ['keywords,date\n',
#  'какая рыба вобла,2023-06-01\n',
#  '"фильмы, мотивирующие на уборку",2023-06-02\n']

# %%
with open('sample.csv') as f:
    for line in f:
        line = line.strip().split(',')
        print(line)
# Out:
# ['keywords', 'date']
# ['какая рыба вобла', '2023-06-01']
# ['"фильмы', ' мотивирующие на уборку"', '2023-06-02']

# %%
import csv

with open('sample.csv') as f:
    reader = csv.reader(f, delimiter=',')

    for line in reader:
        print(line)
# Out:
# ['keywords', 'date']
# ['какая рыба вобла', '2023-06-01']
# ['фильмы, мотивирующие на уборку', '2023-06-02']

# %% [markdown]
# ## Кодировки

# %% [markdown]
# ```
# {"user_id": "user_id", "category": "category"}
# {"category": "РџСРѕРґСѓРєС‚С‹", "user_id": "1840e0b9d4"}
# {"user_id": "4e4f90fcfb", "category": "Р­Р»РµРєС‚СРѕРЅРёРєР°"}
# {"user_id": "afea8d72fc", "category": "Р­Р»РµРєС‚СРѕРЅРёРєР°"}
# {"user_id": "373a6055fe", "category": "Р‘С‹С‚РѕРІР°СЏ С‚РµС…РЅРёРєР°"}
# {"user_id": "9b2ab046f3", "category": "Р­Р»РµРєС‚СРѕРЅРёРєР°"}
# {"user_id": "9f39d307c3", "category": "Р­Р»РµРєС‚СРѕРЅРёРєР°"}
# ```

# %%
10010010101001001010011
# Out:
# 10010010101001001010011

# %%
# перевод чисел из двоичной в десятичную

# %%
# как быть с текстом?
# 'a' --> число

# %% [markdown]
# ### Unicode
# Cтандарт кодирования символов, включающий в себя знаки почти всех письменных языков мир.
#
# Версия самая актуальная - сентябрь 2023 на 149 878  символов.
#
#
# Популярные кодировки - UTF-8, Windows 1251

# %%
ord('a')
# Out:
# 97

# %%
chr(97)
# Out:
# 'a'

# %% [markdown]
# 1. Параметр encoding
# ```python
# open('data.csv', encoding='utf-8')  # cp1251
# ```
# 2. Библиотека chardet угадывает кодировку https://pypi.org/project/chardet/
# 3. Поменять кодировку в текстовом редакторе
# 3. Excel - text import wizard (Data --> Import from text)
# 4. JSON -  текстовый формат обмена данными

# %%
str(['Москва', 'Владивосток'])  # НЕ формат JSON
# Out:
# "['Москва', 'Владивосток']"

# %%
import json

# %%
json.dumps(['Москва', 'Владивосток']) # корректный JSON, но смущает вывод
# Out:
# '["\\u041c\\u043e\\u0441\\u043a\\u0432\\u0430", "\\u0412\\u043b\\u0430\\u0434\\u0438\\u0432\\u043e\\u0441\\u0442\\u043e\\u043a"]'

# %%
with open('json_data.json', 'w') as f:
    json.dump(['Москва', 'Владивосток'], f, ensure_ascii=False)

# %%
with open('json_data.json') as f:
    data = json.load(f)
    print(data)
# Out:
# ['Москва', 'Владивосток']

# %%
json.dumps(['Москва', 'Владивосток'], ensure_ascii=False)  # корректный JSON
# Out:
# '["Москва", "Владивосток"]'

# %% [markdown]
# # (Лекция) Делаем все пошагово

# %% [markdown]
# Опции при открытии файлов:
# - 'r' открыть для чтения. Файл при этом не меняется
# - 'w' открыть файл для записи. Файл при этом полностью чистится (!)
# - 'a' открыть файл для добавления. Файл не меняется, все записи добавляются в конец

# %%
# открываем файл для чтения (опция r)
f = open('visit_log.csv', 'r')

# %%
# прочитать первую строчку
f.readline()
# Out:
# 'user_id,source\n'

# %%
# прочитать еще одну
f.readline()
# Out:
# '6450655ae8,other\n'

# %%
# можно и так
next(f)
# Out:
# 'b4ea53e670,other\n'

# %%
# прочитать все содержимое файла в переменную content
content = f.readlines()

# %%
content[:5]
# Out:
# ['0e37347152,other\n',
#  '96064ae9e0,other\n',
#  'e1bd168161,context\n',
#  '71bcf169b4,other\n',
#  'e0aee73c5d,other\n']

# %%
# построчное чтение файла
for line in f:
    print(line)

    break

# %% [markdown]
# Часто используется конструкция
# ```python
# another_line.strip().split(',')
# ```

# %%
another_line = f.readline()
another_line
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-2320413b673e> in <cell line: 1>()
# ----> 1 another_line = f.readline()
#       2 another_line
#
# ValueError: I/O operation on closed file.

# %%
# удаляем перенос строки и лишние пробелы
another_line.strip()
# Out:
# ''

# %%
# разбиваем столбцы
another_line.strip().split(',')
# Out:
# ['']

# %%
# закрытие файла
f.close()

# %%
# после закрытия не получится прочитать
f.readline()

# %%
# прочитать все строчки файла в список (т. е. в оперативную память)
f = open('visit_log.csv', 'r')

content = f.readlines()

f.close()

# %%
content[:5]
# Out:
# ['user_id,source\n',
#  '6450655ae8,other\n',
#  'b4ea53e670,other\n',
#  '0e37347152,other\n',
#  '96064ae9e0,other\n']

# %% [markdown]
# Запись в файл

# %%
f = open('results.csv', 'w')

# %%
f.write('Начинаю запись первой строки...\n')

# %%
f.write('Начинаю запись второй строки...\n')

# %% [markdown]
# Здесь кто-то еще хочет в него записать

# %%
my_friend_results = open('results.csv', 'w')

# %%
my_friend_results.write('Тут еще результаты есть')

# %%
# пишем свой результат
f.close()

# %%
# и наш результат перезатирается
my_friend_results.close()

# %% [markdown]
# ### Контекстный менеджер
# Как обезопасить себя от подобных накладок

# %%
with open('results.csv', 'w') as f:
    f.write('Начинаю запись первой строки...\n')
    f.write('Начинаю запись второй строки...\n')

    my_friend_results = open('results.csv', 'w')
    my_friend_results.write('Тут еще результаты есть')
    my_friend_results.close()

# %% [markdown]
# ### А можно читать и сразу в файл записывать?
# Напишите функцию, которая фильтрует файл visit_log.csv по источнику context и пишет результат в visits_context.csv. Используйте функцию из второго упражнения для проверки результата.

# %%
with open('visit_log.csv', 'r') as f:
    with open('visits_context.csv', 'w') as f2write:
        for line in f:
            if 'context' in line:
                f2write.write(line)

# %% [markdown]
# ## Чтение списков и словарей из файла
# Смотрим что в файле purchase_log.txt. Похоже тут не строки, а словари

# %%
with open('purchase_log.txt') as f:
    print([next(f) for x in range(5)])
# Out:
# ['{"user_id": "user_id", "category": "category"}\n', '{"user_id": "1840e0b9d4", "category": "Продукты"}\n', '{"user_id": "4e4f90fcfb", "category": "Электроника"}\n', '{"user_id": "afea8d72fc", "category": "Электроника"}\n', '{"user_id": "373a6055fe", "category": "Бытовая техника"}\n']

# %%
import json

# %%
# перевод строки в словарь
dict_in_string = '{"a": 1, "b": 2}'

type(json.loads(dict_in_string))
# Out:
# dict

# %%
# перевод строки в список
list_in_string = '[1, 2, 3]'

json.loads(list_in_string)[-1]
# Out:
# 3

# %%
i = 0
with open('purchase_log.txt') as f:
    for line in f:
        line = line.strip()

        dict_ = json.loads(line)
        print(dict_, type(dict_))

        i += 1
        if i > 5:
            break
# Out:
# {'user_id': 'user_id', 'category': 'category'} <class 'dict'>
# {'user_id': '1840e0b9d4', 'category': 'Продукты'} <class 'dict'>
# {'user_id': '4e4f90fcfb', 'category': 'Электроника'} <class 'dict'>
# {'user_id': 'afea8d72fc', 'category': 'Электроника'} <class 'dict'>
# {'user_id': '373a6055fe', 'category': 'Бытовая техника'} <class 'dict'>
# {'user_id': '9b2ab046f3', 'category': 'Электроника'} <class 'dict'>

# %% [markdown]
# ### Из словаря в строку тоже можно

# %%
data = {'user_id': '1840e0b9d4', 'category': 'Продукты'}

# %%
json.dumps(data)
# Out:
# '{"user_id": "1840e0b9d4", "category": "\\u041f\\u0440\\u043e\\u0434\\u0443\\u043a\\u0442\\u044b"}'

# %%
type(json.dumps(data))
# Out:
# str

# %% [markdown]
# ## Модуль pickle
# Запись объекта сразу в файл как поток байтов

# %%
import pickle

# %%
data = {'user_id': '1840e0b9d4', 'category': 'Продукты'}

# %%
with open('data.pickle', 'wb') as f:
    pickle.dump(data, f)

# %%
# прочитать объект из такого файла

with open('data.pickle', 'rb') as f:
    dict_ = pickle.load(f)

dict_, dict_['user_id']
# Out:
# ({'user_id': '1840e0b9d4', 'category': 'Продукты'}, '1840e0b9d4')

# %% [markdown]
# ## Чтение файлов из папки

# %%
import os

# %%
# чтение файлов и папок
for file in os.listdir('data'):
    print(file)

# %%
# чтение всех файлов и папок, в том числе вложенных
for root, directory, file in os.walk('data'):
    print(root, directory, file)

# %% [markdown]
# ## Каталог пакетов pip (Python Package Index)
# Варианты установки
# 1. С помощью Anaconda Navigator
# 2. В командной строке (Terminal на маке)
# ```bash
# pip install package_name
# ```
# 3. Скачать версию с github и установить вручную
# ```bash
# pip install .
# ```
#
# Пакеты устанавливаются в определенное окружение! Вам пригодится virtualenv

# %%
# !pip install plotly

# %%
import plotly

# %% [markdown]
# ## Домашнее задание
# 1. Переведите содержимое файла purchase_log.txt в словарь purchases вида:
# ```python
# {'1840e0b9d4': 'Продукты', ...}
# ```
#
# 2. Для каждого user_id в файле visit_log.csv определите третий столбец с категорией покупки (если покупка была, сам файл visit_log.csv изменять не надо). Запишите в файл funnel.csv визиты из файла visit_log.csv, в которых были покупки с указанием категории.
#
# Учтите условия на данные:
# - содержимое purchase_log.txt помещается в оперативную память компьютера
# - содержимое visit_log.csv - нет; используйте только построчную обработку этого файла

# %% [markdown]
# # Новый раздел

# %%
# такие решения засчитываться не будут
for line in f:
    line.split('{')[-14:-9].split(',')

# такое будет
for line in f:
    line = json.loads(line)

# %%
import csv


with open('visit_log.csv') as f:
    reader = csv.reader(f, delimiter=',')

    i = 0
    for line in reader:
        print(line)
        i += 1

        if i > 5:
          break
# Out:
# ['user_id', 'source']
# ['6450655ae8', 'other']
# ['b4ea53e670', 'other']
# ['0e37347152', 'other']
# ['96064ae9e0', 'other']
# ['e1bd168161', 'context']

# %%
# найти ключ в словаре - НЕПРАВИЛЬНО - 40мин
for line in f_visits:
    for key, value in purchases.items():
        for key == user_id:
            ...

# %%
100000 * 200000
# Out:
# 20000000000

# %%
# найти ключ в словаре - работает ~ 1сек
for line in f_visits:
    if user_id in purchases:  # поиск по словарю НЕ зависит от его размера
