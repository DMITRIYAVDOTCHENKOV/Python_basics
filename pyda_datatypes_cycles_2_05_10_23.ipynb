# %% [markdown]
# # Практика 3
# Теория: Типы данных и циклы. Часть 2
#
# Булыгин Олег:
# * [LinkedIn](linkedin.com/in/obulygin)
# * [Мой канал в ТГ по Python](https://t.me/pythontalk_ru)
# * [Чат канала](https://t.me/pythontalk_chat)
# * [Блог в Телетайпе](https://teletype.in/@pythontalk)

# %% [markdown]
# 1.   Пару полезностей
# 2.   [list comprehension](https://teletype.in/@pythontalk/list_comprehension)
# 3.   Словари
# 4.   [dict comprehension](https://teletype.in/@pythontalk/dictionary_comprehension)
# 5.   Множества

# %% [markdown]
# Напишем программу для проверки логина и пароля
#
# 1) логин и пароль пользователя хранится в переменной
#
# 2) будем давать пользователю k попыток на ввод логина и пароля
#
# 3) если после трех попыток вверного ввода не было, то заблокируем вход - вывести на экран сообщение "Вход заблокирован"
#
# 4) если пароль и логин были введены верно, то вывести на экран сообщение "Добро пожаловать!"

# %%
login_correct = 'admin'
pswd_correct = 'admin'
k = 3
for i in range(k):
    login = input('Ввеите логин')
    pswd = input('Введите пароль')
    if login != login_correct or pswd != pswd_correct:
        k -= 1
        print(f'Осталось {k} попытки')
    else:
        print('Добро пожаловать!')
        break
else:
    print('Вход заблокирован')
# Out:
# Ввеите логинadmin
# Введите пароль3467
# Осталось 2 попытки
# Ввеите логинoerih
# Введите парольadmin
# Осталось 1 попытки
# Ввеите логинrh
# Введите парольerh
# Осталось 0 попытки
# Вход заблокирован

# %%
countries_temperature = [
    ['Таиланд', [75.2, 77, 78.8, 73.4, 68, 75.2, 77]],
    ['Германия', [57.2, 55.4, 59, 59, 53.6]],
    ['Россия', [35.6, 37.4, 39.2, 41, 42.8, 39.2, 35.6]],
    ['Польша', [50, 50, 53.6, 57.2, 55.4, 55.4]]]

for country, temps in countries_temperature:
    # print(country)
    # print(temps)
    print(f'{} {} ')
# Out:
# Таиланд
# [75.2, 77, 78.8, 73.4, 68, 75.2, 77]
# Германия
# [57.2, 55.4, 59, 59, 53.6]
# Россия
# [35.6, 37.4, 39.2, 41, 42.8, 39.2, 35.6]
# Польша
# [50, 50, 53.6, 57.2, 55.4, 55.4]

# %% [markdown]
# Решим задачу с диагональной матрицей в одну строку

# %%
data = [
    [13, 25, 23, 34],
    [45, 32, 44, 47],
    [12, 33, 23, 95],
    [13, 53, 34, 35]
]

# %%
# в прошлый раз было вот такое решение
result = 0
index = 0
for row in data:
    result += row[index]
    index += 1
print(result)

# %%
tuple(enumerate(data))
# Out:
# ((0, [13, 25, 23, 34]),
#  (1, [45, 32, 44, 47]),
#  (2, [12, 33, 23, 95]),
#  (3, [13, 53, 34, 35]))

# %%
result = 0

for index, el in enumerate(data):
    # print(index)
    # print(el)
    result += el[index]

result
# Out:
# 0
# [13, 25, 23, 34]
# 1
# [45, 32, 44, 47]
# 2
# [12, 33, 23, 95]
# 3
# [13, 53, 34, 35]
# 103

# %%
sum([el[index] for index, el in enumerate(data)])
# Out:
# 103

# %%
for index, el in enumerate('hello'):
    print(index, el)
# Out:
# 0 h
# 1 e
# 2 l
# 3 l
# 4 o

# %%
[row for row in data]

# %%
[sum(row) for row in data]
# Out:
# [95, 168, 163, 135]

# %% [markdown]
# Выведем информацию о странах и столициах в виде:
#  `The capital of ... is ...`

# %%
europe = {'spain': {'capital': 'madrid'},
           'france': {'capital': 'paris'},
           'germany': {'capital': 'berlin'},
           'norway': {'capital': 'oslo'}}

europe.keys()
# Out:
# dict_keys(['spain', 'france', 'germany', 'norway'])

# %%
for info in europe.values():
    print(info['capital'])
# Out:
# madrid
# paris
# berlin
# oslo

# %%
[info['capital'] for info in europe.values()]
# Out:
# ['madrid', 'paris', 'berlin', 'oslo']

# %%
for country, info in europe.items():
    # print(country, info.keys())
    print(f'The capital of {country.capitalize()} is {info["capital"].capitalize()}')
# Out:
# The capital of Spain is Madrid
# The capital of France is Paris
# The capital of Germany is Berlin
# The capital of Norway is Oslo

# %% [markdown]
# Посчитаем средний возраст в коллективе

# %%
people = {1: {'name': 'Oleg', 'age': '29', 'sex': 'Male'},
          2: {'name': 'Kate', 'age': '21', 'sex': 'Female'},
          3: {'name': 'Liza', 'age': '24', 'sex': 'Female'},
          4: {'name': 'Pavel', 'age': '36', 'sex': 'Male'}}

# %%
people.values()
# Out:
# dict_values([{'name': 'Oleg', 'age': '29', 'sex': 'Male'}, {'name': 'Kate', 'age': '21', 'sex': 'Female'}, {'name': 'Liza', 'age': '24', 'sex': 'Female'}, {'name': 'Pavel', 'age': '36', 'sex': 'Male'}])

# %%
age = 0
for person in people.values():
    age += int(person['age'])
print(age / len(people))
# Out:
# 27.5

# %%
[int(person['age']) for person in people.values()]
# Out:
# [29, 21, 24, 36]

# %%
people = {1: {'name': 'Oleg', 'age': '29', 'sex': 'Male'},
          2: {'name': 'Kate', 'age': '21', 'sex': 'Female'},
          3: {'name': 'Liza', 'age': '24', 'sex': 'Female'},
          4: {'name': 'Pavel', 'age': '36', 'sex': 'Male'}}

# %%
people.values()
# Out:
# dict_values([{'name': 'Oleg', 'age': '29', 'sex': 'Male'}, {'name': 'Kate', 'age': '21', 'sex': 'Female'}, {'name': 'Liza', 'age': '24', 'sex': 'Female'}, {'name': 'Pavel', 'age': '36', 'sex': 'Male'}])

# %%
for el in people.values():
    print(el)
# Out:
# {'name': 'Oleg', 'age': '29', 'sex': 'Male'}
# {'name': 'Kate', 'age': '21', 'sex': 'Female'}
# {'name': 'Liza', 'age': '24', 'sex': 'Female'}
# {'name': 'Pavel', 'age': '36', 'sex': 'Male'}

# %%
sum(int(for age in people.values()))

# %%
sum([int(el['age']) for el in people.values()]) / len(people)
# Out:
# 27.5

# %% [markdown]
# https://teletype.in/@pythontalk/list_comprehension_adv

# %% [markdown]
# Удалим из словаря все пустые элементы (со значением None)

# %%
my_dict = {
    'id1': 123456,
    'id2': 654321,
    'id3': None,
    'id4': 777777
}

# %%
res = {}

for key, value in my_dict.items():
    if value is not None:
        res[key] = value

res
# Out:
# {'id1': 123456, 'id2': 654321, 'id4': 777777}

# %%
{key: value for key, value in my_dict.items() if value is not None}
# Out:
# {'id1': 123456, 'id2': 654321, 'id4': 777777}

# %% [markdown]
# https://t.me/pythontalk_ru/1332

# %% [markdown]
# Посчитаем сколько раз каждое слово встречалось в тексте и выведем информацию в виде:
# `"слово": "количество вхождений" `

# %%
some_text = '''
Python — высокоуровневый язык программирования общего назначения с динамической строгой типизацией и автоматическим управлением памятью,
ориентированный на повышение производительности разработчика, читаемости кода и его качества, а также на обеспечение переносимости написанных на нём программ.
Язык является полностью объектно-ориентированным в том плане, что всё является объектами.
Необычной особенностью языка является выделение блоков кода пробельными отступами.
'''

# %%
import re

res = {}

for word in re.sub(r'[^\w\s-]', '', some_text).lower().split():
    # print(word)
    # word = word.strip('!?,.()')
    if word in res:
        res[word] += 1
    else:
        res[word] = 1

for word, count in res.items():
    print(f'{word} - {count}')
# Out:
# python - 1
# высокоуровневый - 1
# язык - 2
# программирования - 1
# общего - 1
# назначения - 1
# с - 1
# динамической - 1
# строгой - 1
# типизацией - 1
# и - 2
# автоматическим - 1
# управлением - 1
# памятью - 1
# ориентированный - 1
# на - 3
# повышение - 1
# производительности - 1
# разработчика - 1
# читаемости - 1
# кода - 2
# его - 1
# качества - 1
# а - 1
# также - 1
# обеспечение - 1
# переносимости - 1
# написанных - 1
# нём - 1
# программ - 1
# является - 3
# полностью - 1
# объектно-ориентированным - 1
# в - 1
# том - 1
# плане - 1
# что - 1
# всё - 1
# объектами - 1
# необычной - 1
# особенностью - 1
# языка - 1
# выделение - 1
# блоков - 1
# пробельными - 1
# отступами - 1

# %%
import re

res = {}

for word in re.sub(r'[^\w\s-]', '', some_text).lower().split():
    res.setdefault(word, 0)
    res[word] += 1

for word, count in res.items():
    print(f'{word} - {count}')
# Out:
# python - 1
# высокоуровневый - 1
# язык - 2
# программирования - 1
# общего - 1
# назначения - 1
# с - 1
# динамической - 1
# строгой - 1
# типизацией - 1
# и - 2
# автоматическим - 1
# управлением - 1
# памятью - 1
# ориентированный - 1
# на - 3
# повышение - 1
# производительности - 1
# разработчика - 1
# читаемости - 1
# кода - 2
# его - 1
# качества - 1
# а - 1
# также - 1
# обеспечение - 1
# переносимости - 1
# написанных - 1
# нём - 1
# программ - 1
# является - 3
# полностью - 1
# объектно-ориентированным - 1
# в - 1
# том - 1
# плане - 1
# что - 1
# всё - 1
# объектами - 1
# необычной - 1
# особенностью - 1
# языка - 1
# выделение - 1
# блоков - 1
# пробельными - 1
# отступами - 1

# %%
import re

res = {}

for word in re.sub(r'[^\w\s-]', '', some_text).lower().split():
    res[word] = res.get(word, 0) + 1

for word, count in res.items():
    print(f'{word} - {count}')
# Out:
# python - 1
# высокоуровневый - 1
# язык - 2
# программирования - 1
# общего - 1
# назначения - 1
# с - 1
# динамической - 1
# строгой - 1
# типизацией - 1
# и - 2
# автоматическим - 1
# управлением - 1
# памятью - 1
# ориентированный - 1
# на - 3
# повышение - 1
# производительности - 1
# разработчика - 1
# читаемости - 1
# кода - 2
# его - 1
# качества - 1
# а - 1
# также - 1
# обеспечение - 1
# переносимости - 1
# написанных - 1
# нём - 1
# программ - 1
# является - 3
# полностью - 1
# объектно-ориентированным - 1
# в - 1
# том - 1
# плане - 1
# что - 1
# всё - 1
# объектами - 1
# необычной - 1
# особенностью - 1
# языка - 1
# выделение - 1
# блоков - 1
# пробельными - 1
# отступами - 1

# %%
dict(sorted(res.items(), key=lambda x: x[1], reverse=True))
# Out:
# {'на': 3,
#  'является': 3,
#  'язык': 2,
#  'и': 2,
#  'кода': 2,
#  'python': 1,
#  'высокоуровневый': 1,
#  'программирования': 1,
#  'общего': 1,
#  'назначения': 1,
#  'с': 1,
#  'динамической': 1,
#  'строгой': 1,
#  'типизацией': 1,
#  'автоматическим': 1,
#  'управлением': 1,
#  'памятью': 1,
#  'ориентированный': 1,
#  'повышение': 1,
#  'производительности': 1,
#  'разработчика': 1,
#  'читаемости': 1,
#  'его': 1,
#  'качества': 1,
#  'а': 1,
#  'также': 1,
#  'обеспечение': 1,
#  'переносимости': 1,
#  'написанных': 1,
#  'нём': 1,
#  'программ': 1,
#  'полностью': 1,
#  'объектно-ориентированным': 1,
#  'в': 1,
#  'том': 1,
#  'плане': 1,
#  'что': 1,
#  'всё': 1,
#  'объектами': 1,
#  'необычной': 1,
#  'особенностью': 1,
#  'языка': 1,
#  'выделение': 1,
#  'блоков': 1,
#  'пробельными': 1,
#  'отступами': 1}

# %%
for letter in re.sub(r'[^\w\s-]', '', some_text).lower():
    print(letter)
# Out:
# p
# y
# t
# h
# o
# n
#
#
# в
# ы
# с
# о
# к
# о
# у
# р
# о
# в
# н
# е
# в
# ы
# й
#
# я
# з
# ы
# к
#
# п
# р
# о
# г
# р
# а
# м
# м
# и
# р
# о
# в
# а
# н
# и
# я
#
# о
# б
# щ
# е
# г
# о
#
# н
# а
# з
# н
# а
# ч
# е
# н
# и
# я
#
# с
#
# д
# и
# н
# а
# м
# и
# ч
# е
# с
# к
# о
# й
#
# с
# т
# р
# о
# г
# о
# й
#
# т
# и
# п
# и
# з
# а
# ц
# и
# е
# й
#
# и
#
# а
# в
# т
# о
# м
# а
# т
# и
# ч
# е
# с
# к
# и
# м
#
# у
# п
# р
# а
# в
# л
# е
# н
# и
# е
# м
#
# п
# а
# м
# я
# т
# ь
# ю
#
#
# о
# р
# и
# е
# н
# т
# и
# р
# о
# в
# а
# н
# н
# ы
# й
#
# н
# а
#
# п
# о
# в
# ы
# ш
# е
# н
# и
# е
#
# п
# р
# о
# и
# з
# в
# о
# д
# и
# т
# е
# л
# ь
# н
# о
# с
# т
# и
#
# р
# а
# з
# р
# а
# б
# о
# т
# ч
# и
# к
# а
#
# ч
# и
# т
# а
# е
# м
# о
# с
# т
# и
#
# к
# о
# д
# а
#
# и
#
# е
# г
# о
#
# к
# а
# ч
# е
# с
# т
# в
# а
#
# а
#
# т
# а
# к
# ж
# е
#
# н
# а
#
# о
# б
# е
# с
# п
# е
# ч
# е
# н
# и
# е
#
# п
# е
# р
# е
# н
# о
# с
# и
# м
# о
# с
# т
# и
#
# ...

# %%
import re

res = {}

for word in re.sub(r'[^\w\s-]', '', some_text).lower():
    # print(word)
    # word = word.strip('!?,.()')
    if word in res:
        res[word] += 1
    else:
        res[word] = 1

for word, count in res.items():
    print(f'{word} - {count}')
# Out:
#  - 5
# p - 1
# y - 1
# t - 1
# h - 1
# o - 1
# n - 1
#   - 50
# в - 18
# ы - 12
# с - 20
# о - 44
# к - 14
# у - 3
# р - 17
# н - 33
# е - 35
# й - 6
# я - 15
# з - 7
# п - 14
# г - 5
# а - 32
# м - 17
# и - 32
# б - 9
# щ - 1
# ч - 9
# д - 5
# т - 26
# ц - 1
# л - 10
# ь - 5
# ю - 3
# ш - 1
# ж - 1
# х - 1
# ё - 2
# ъ - 2
# - - 1

# %%
splitted_text = re.sub(r'[^\w\s-]', '', some_text).lower().split()

for word in set(splitted_text):
    print(f'{word} - {splitted_text.count(word)}')
# Out:
# а - 1
# кода - 2
# автоматическим - 1
# написанных - 1
# общего - 1
# нём - 1
# типизацией - 1
# полностью - 1
# том - 1
# программирования - 1
# читаемости - 1
# ориентированный - 1
# в - 1
# python - 1
# переносимости - 1
# выделение - 1
# разработчика - 1
# высокоуровневый - 1
# качества - 1
# также - 1
# особенностью - 1
# обеспечение - 1
# его - 1
# необычной - 1
# отступами - 1
# и - 2
# программ - 1
# динамической - 1
# памятью - 1
# назначения - 1
# всё - 1
# производительности - 1
# с - 1
# что - 1
# на - 3
# управлением - 1
# объектами - 1
# блоков - 1
# является - 3
# язык - 2
# пробельными - 1
# строгой - 1
# повышение - 1
# языка - 1
# плане - 1
# объектно-ориентированным - 1

# %%
some_text = '''
Python — высокоуровневый язык программирования общего назначения с динамической строгой типизацией и автоматическим управлением памятью,
ориентированный на повышение производительности разработчика, читаемости кода и его качества, а также на обеспечение переносимости написанных на нём программ.
Язык является полностью объектно-ориентированным в том плане, что всё является объектами.
Необычной особенностью языка является выделение блоков кода пробельными отступами.
'''

splitted_text = re.sub(r'[^\w\s-]', '', some_text).lower().split()
# print(splitted_text)

for word in set(splitted_text):
    print(f'{word} - {splitted_text.count(word)}')
# Out:
# а - 1
# кода - 2
# автоматическим - 1
# написанных - 1
# общего - 1
# нём - 1
# типизацией - 1
# полностью - 1
# том - 1
# программирования - 1
# читаемости - 1
# ориентированный - 1
# в - 1
# python - 1
# переносимости - 1
# выделение - 1
# разработчика - 1
# высокоуровневый - 1
# качества - 1
# также - 1
# особенностью - 1
# обеспечение - 1
# его - 1
# необычной - 1
# отступами - 1
# и - 2
# программ - 1
# динамической - 1
# памятью - 1
# назначения - 1
# всё - 1
# производительности - 1
# с - 1
# что - 1
# на - 3
# управлением - 1
# объектами - 1
# блоков - 1
# является - 3
# язык - 2
# пробельными - 1
# строгой - 1
# повышение - 1
# языка - 1
# плане - 1
# объектно-ориентированным - 1

# %%
some_text = '''
Python — высокоуровневый язык программирования общего назначения с динамической строгой типизацией и автоматическим управлением памятью,
ориентированный на повышение производительности разработчика, читаемости кода и его качества, а также на обеспечение переносимости написанных на нём программ.
Язык является полностью объектно-ориентированным в том плане, что всё является объектами.
Необычной особенностью языка является выделение блоков кода пробельными отступами.
'''

splitted_text = re.sub(r'[^\w\s-]', '', some_text).lower().split()
# print(splitted_text)

for word in set(splitted_text):
    print(f'{word} - {splitted_text.count(word)}')
    for letter in set(word):
        print(f'\t{letter} - {word.count(letter)}')
# Out:
# а - 1
# 	а - 1
# кода - 2
# 	о - 1
# 	а - 1
# 	к - 1
# 	д - 1
# автоматическим - 1
# 	а - 2
# 	к - 1
# 	в - 1
# 	о - 1
# 	и - 2
# 	т - 2
# 	с - 1
# 	е - 1
# 	ч - 1
# 	м - 2
# написанных - 1
# 	а - 2
# 	ы - 1
# 	и - 1
# 	п - 1
# 	х - 1
# 	с - 1
# 	н - 3
# общего - 1
# 	г - 1
# 	о - 2
# 	щ - 1
# 	е - 1
# 	б - 1
# нём - 1
# 	ё - 1
# 	м - 1
# 	н - 1
# типизацией - 1
# 	а - 1
# 	з - 1
# 	и - 3
# 	п - 1
# 	т - 1
# 	е - 1
# 	ц - 1
# 	й - 1
# полностью - 1
# 	ь - 1
# 	о - 2
# 	п - 1
# 	л - 1
# 	т - 1
# 	ю - 1
# 	с - 1
# 	н - 1
# том - 1
# 	м - 1
# 	т - 1
# 	о - 1
# программирования - 1
# 	г - 1
# 	а - 2
# 	о - 2
# 	в - 1
# 	я - 1
# 	и - 2
# 	р - 3
# 	п - 1
# 	м - 2
# 	н - 1
# читаемости - 1
# 	а - 1
# 	о - 1
# 	и - 2
# 	т - 2
# 	с - 1
# 	е - 1
# 	ч - 1
# 	м - 1
# ориентированный - 1
# 	а - 1
# 	о - 2
# 	в - 1
# 	ы - 1
# 	и - 2
# 	р - 2
# 	т - 1
# 	й - 1
# 	е - 1
# 	н - 3
# в - 1
# 	в - 1
# python - 1
# 	o - 1
# 	p - 1
# 	h - 1
# 	y - 1
# 	t - 1
# 	n - 1
# переносимости - 1
# 	о - 2
# 	и - 2
# ...

# %%
Counter

# %% [markdown]
# Проблема изменение длины объекта во время итерации по нему

# %% [markdown]
# Дан список с визитами по городам и странам.
# Напишем код, который возвращает отфильтрованный список `geo_logs`, содержащий только визиты из России.

# %%
geo_logs = [
    {'visit1': ['Москва', 'Россия']},
    {'visit2': ['Дели', 'Индия']},
    {'visit3': ['Владимир', 'Россия']},
    {'visit4': ['Лиссабон', 'Португалия']},
    {'visit5': ['Париж', 'Франция']},
    {'visit7': ['Тула', 'Россия']},
    {'visit9': ['Курск', 'Россия']},
    {'visit10': ['Архангельск', 'Россия']}
]

# %%
for log in geo_logs:
    for el in log.values():
        if 'Россия' not in el:
            geo_logs.remove(log)

geo_logs
# Out:
# [{'visit1': ['Москва', 'Россия']},
#  {'visit3': ['Владимир', 'Россия']},
#  {'visit5': ['Париж', 'Франция']},
#  {'visit7': ['Тула', 'Россия']},
#  {'visit9': ['Курск', 'Россия']},
#  {'visit10': ['Архангельск', 'Россия']}]

# %%
res = []

for log in geo_logs:
    # print(list(log.values())[0])
    if 'Россия' in list(log.values())[0]:
        res.append(log)

res
# Out:
# [{'visit1': ['Москва', 'Россия']},
#  {'visit3': ['Владимир', 'Россия']},
#  {'visit7': ['Тула', 'Россия']},
#  {'visit9': ['Курск', 'Россия']},
#  {'visit10': ['Архангельск', 'Россия']}]

# %%
res = [log for log in geo_logs if 'Россия' in list(log.values())[0]]
# Out:
# [{'visit1': ['Москва', 'Россия']},
#  {'visit3': ['Владимир', 'Россия']},
#  {'visit7': ['Тула', 'Россия']},
#  {'visit9': ['Курск', 'Россия']},
#  {'visit10': ['Архангельск', 'Россия']}]

# %% [markdown]
# Посмотрим, как знание сложных структур может помочь в задачах, приближенных к реальным

# %%
import requests
import time
# функция pprint позволяет более структурированно выводить сложные структуры
token = ''

# %% [markdown]
# Поищем сообщества в социальной сети

# %%
params = {
    'q': 'python',
    'access_token': token,
    'v':'5.131',
    'count': 300
}
req = requests.get('https://api.vk.com/method/groups.search', params).json()

# %%
req
# Out:
# {'response': {'count': 779,
#   'items': [{'id': 174948538,
#     'name': 'Python',
#     'screen_name': 'python_forum',
#     'is_closed': 0,
#     'type': 'group',
#     'photo_50': 'https://sun1-84.userapi.com/s/v1/if1/MEYBAJy7-F0hhO0kE6_k0ojC4EI7u_MLgmHsD48133hYVCZcIV-XeQR5rFjx8Ck3G1Anj6Q-.jpg?size=50x50&quality=96&crop=231,103,561,561&ava=1',
#     'photo_100': 'https://sun1-84.userapi.com/s/v1/if1/o7H_iDwVS0azUTVk0g3vXpi4ouVHZOwkrSwt5v-7letDl4kbZSlduymQcuYt3tSI3DXQMLcI.jpg?size=100x100&quality=96&crop=231,103,561,561&ava=1',
#     'photo_200': 'https://sun1-84.userapi.com/s/v1/if1/cQWaClxNxL0IfOea_6I8LCrZZ7nAFy2IF9_FXj_-8f5Z6cwpAc4M4QYfygy6rQv_YgYwJWMj.jpg?size=200x200&quality=96&crop=231,103,561,561&ava=1'},
#    {'id': 152111071,
#     'name': 'Python',
#     'screen_name': 'python_django_programirovanie',
#     'is_closed': 0,
#     'type': 'group',
# ...

# %%
target_groups = req['response']['items']
target_groups
# Out:
# [{'id': 174948538,
#   'name': 'Python',
#   'screen_name': 'python_forum',
#   'is_closed': 0,
#   'type': 'group',
#   'photo_50': 'https://sun1-84.userapi.com/s/v1/if1/MEYBAJy7-F0hhO0kE6_k0ojC4EI7u_MLgmHsD48133hYVCZcIV-XeQR5rFjx8Ck3G1Anj6Q-.jpg?size=50x50&quality=96&crop=231,103,561,561&ava=1',
#   'photo_100': 'https://sun1-84.userapi.com/s/v1/if1/o7H_iDwVS0azUTVk0g3vXpi4ouVHZOwkrSwt5v-7letDl4kbZSlduymQcuYt3tSI3DXQMLcI.jpg?size=100x100&quality=96&crop=231,103,561,561&ava=1',
#   'photo_200': 'https://sun1-84.userapi.com/s/v1/if1/cQWaClxNxL0IfOea_6I8LCrZZ7nAFy2IF9_FXj_-8f5Z6cwpAc4M4QYfygy6rQv_YgYwJWMj.jpg?size=200x200&quality=96&crop=231,103,561,561&ava=1'},
#  {'id': 152111071,
#   'name': 'Python',
#   'screen_name': 'python_django_programirovanie',
#   'is_closed': 0,
#   'type': 'group',
#   'photo_50': 'https://sun1-30.userapi.com/s/v1/if1/A6k7o-6-9iusZf0ErItZASlQfDaGBHh3WE3eJ4qg9vgJA60dJqNHkHLebmyT3CgLNQSe1w.jpg?size=50x50&quality=96&crop=260,83,441,441&ava=1',
# ...

# %%
# преобразуем список всех id в строку (в таком виде принимает данные параметр fields)
target_group_ids = ','.join([str(group['id']) for group in target_groups])
print(target_group_ids)
# Out:
# 174948538,152111071,206098555,52104930,216360964,216361171,42565717,194576836,13765414,193480984,69108280,41943023,64524646,210425581,38080744,172171969,149218373,3183750,11899736,205121478,96469126,185939737,107124511,80460037,32444405,191744477,140154120,209077931,219306139,75654972,156528136,24847633,196848333,174586137,216109660,215884645,178733625,173695051,179461859,97789166,109938878,180288349,97159757,199867860,219236694,216361162,213921955,158994985,73929027,207899503,78600915,164946472,218852589,181513077,212187812,82087650,212765563,165919087,216677456,216460846,219945419,187244583,220418447,61424979,172288069,182884580,205988839,219193244,213922645,213922761,172192793,45964980,217288565,216228113,163875533,195434119,217633213,222500101,96806600,125409792,207629753,216439178,204886867,191919646,177962775,181854671,155841294,222043154,183738581,85364050,209530570,189204591,186894419,178774705,41069912,221853226,161474904,146398718,192839752,222615434,219512094,183439669,217
# ...

# %%
params = {
    'access_token': token,
    'v':'5.131',
    'group_ids': target_group_ids,
    'fields':  'members_count,activity,description'

}
req = requests.get('https://api.vk.com/method/groups.getById', params)

req.json()
# Out:
# {'response': [{'id': 174948538,
#    'description': 'Группа любителей и профессионалов языка программирования Питон/Пайтон (Python). Новости, видео, статьи, книги и помощь.',
#    'members_count': 20567,
#    'activity': 'Программирование',
#    'name': 'Python',
#    'screen_name': 'python_forum',
#    'is_closed': 0,
#    'type': 'group',
#    'photo_50': 'https://sun1-84.userapi.com/s/v1/if1/MEYBAJy7-F0hhO0kE6_k0ojC4EI7u_MLgmHsD48133hYVCZcIV-XeQR5rFjx8Ck3G1Anj6Q-.jpg?size=50x50&quality=96&crop=231,103,561,561&ava=1',
#    'photo_100': 'https://sun1-84.userapi.com/s/v1/if1/o7H_iDwVS0azUTVk0g3vXpi4ouVHZOwkrSwt5v-7letDl4kbZSlduymQcuYt3tSI3DXQMLcI.jpg?size=100x100&quality=96&crop=231,103,561,561&ava=1',
#    'photo_200': 'https://sun1-84.userapi.com/s/v1/if1/cQWaClxNxL0IfOea_6I8LCrZZ7nAFy2IF9_FXj_-8f5Z6cwpAc4M4QYfygy6rQv_YgYwJWMj.jpg?size=200x200&quality=96&crop=231,103,561,561&ava=1'},
#   {'id': 152111071,
# ...

# %% [markdown]
# Посчитаем количество лайков в сообщениях

# %%
params = {
    'access_token': token,
    'v':'5.131',
    'q': 'Нетология',
    'start_from': '',
    'count': 200,
    'extended': 1
}
res = []
while True:
    result = requests.get('https://api.vk.com/method/newsfeed.search', params)
    time.sleep(0.33)
    res += result.json()['response']['items']
    if 'next_from' in result.json()['response'].keys():
        params['start_from'] = result.json()['response']['next_from']
    else:
        break

# %%
print(type(res))
print(len(res))
# Out:
# <class 'list'>
# 944

# %%
res[0]
# Out:
# {'donut': {'is_donut': False},
#  'comments': {'can_post': 1, 'count': 0, 'groups_can_post': True},
#  'marked_as_ads': 1,
#  'short_text_rate': 0.8,
#  'type': 'post',
#  'carousel_offset': 0,
#  'attachments': [{'type': 'photo',
#    'photo': {'album_id': -51,
#     'date': 1696322015,
#     'id': 457254401,
#     'owner_id': -210610456,
#     'access_key': '2aff56a3866e4028e0',
#     'sizes': [{'height': 75,
#       'type': 's',
#       'width': 75,
#       'url': 'https://sun1-85.userapi.com/impg/85WwcDtR7AUy7o9pyU-wNPV4kLXOK4yf9xA6JQ/ZZEiwCoujHE.jpg?size=75x75&quality=95&sign=3b018e05ac4f28b8e05c723fc8085c9c&c_uniq_tag=F9oxDzDV3ijNRnsdUq9aM3JvlhBr2Wus0OcaGASMpIA&type=album'},
#      {'height': 130,
#       'type': 'm',
#       'width': 130,
#       'url': 'https://sun1-85.userapi.com/impg/85WwcDtR7AUy7o9pyU-wNPV4kLXOK4yf9xA6JQ/ZZEiwCoujHE.jpg?size=130x130&quality=95&sign=bf8895ddc2d584ba0a9659a61b34e541&c_uniq_tag=tatpYR53-Zt37Htka2MT8llVicD4z9jszot8WbC6S1k&type=album'},
# ...

# %%
# посчитаем количество лайклов и репостов
likes_count = 0
reposts_count = 0
for post in res:
    likes_count += post['likes']['count']
    reposts_count += post['reposts']['count']

print(likes_count)
print(reposts_count)
# Out:
# 6459
# 1858

# %%
my_list = ['2018-01-01', 'yandex', 'cpc', 100]

# {'2018-01-01': {'yandex': {'cpc': 100}}}

res = my_list[-1]

for el in reversed(my_list[:-1]):
    res = ...
# Out:
# {'cpc': 100}
# {'yandex': 100}
# {'2018-01-01': 100}
